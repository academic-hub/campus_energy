# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Overall-Learning-Objectives" data-toc-modified-id="Overall-Learning-Objectives-1">Overall Learning Objectives</a></span><ul class="toc-item"><li><span><a href="#Introduction-to-the-OSIsoft-Academic-Hub,-Operational-Data,-and-OSIsoft" data-toc-modified-id="Introduction-to-the-OSIsoft-Academic-Hub,-Operational-Data,-and-OSIsoft-1.1">Introduction to the OSIsoft Academic Hub, Operational Data, and OSIsoft</a></span></li><li><span><a href="#Overview-of-the-Campus-Dataset-Document" data-toc-modified-id="Overview-of-the-Campus-Dataset-Document-1.2">Overview of the Campus Dataset Document</a></span></li></ul></li><li><span><a href="#Part-1.-Description-of-Campus-Energy-Dataset-(UC-Davis)" data-toc-modified-id="Part-1.-Description-of-Campus-Energy-Dataset-(UC-Davis)-2">Part 1. Description of Campus Energy Dataset (UC Davis)</a></span><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#1a.-Presence-of--electricity/chilled-water/steam-for-each-building" data-toc-modified-id="1a.-Presence-of--electricity/chilled-water/steam-for-each-building-2.0.1">1a. Presence of  electricity/chilled water/steam for each building</a></span></li><li><span><a href="#1b.-UC-Davis-Smart-Campus" data-toc-modified-id="1b.-UC-Davis-Smart-Campus-2.0.2">1b. UC Davis Smart Campus</a></span></li></ul></li></ul></li><li><span><a href="#Part-2.-Smart-Campus-Challenges-and-Goals" data-toc-modified-id="Part-2.-Smart-Campus-Challenges-and-Goals-3">Part 2. Smart Campus Challenges and Goals</a></span></li><li><span><a href="#Part-3.-Stream-Data" data-toc-modified-id="Part-3.-Stream-Data-4">Part 3. Stream Data</a></span></li><li><span><a href="#Part-4.-Data-Quality" data-toc-modified-id="Part-4.-Data-Quality-5">Part 4. Data Quality</a></span></li><li><span><a href="#Part-5.-Assets,-Dataviews-and-Metadata" data-toc-modified-id="Part-5.-Assets,-Dataviews-and-Metadata-6">Part 5. Assets, Dataviews and Metadata</a></span><ul class="toc-item"><li><span><a href="#Campus-Assets:-Buildings" data-toc-modified-id="Campus-Assets:-Buildings-6.1">Campus Assets: Buildings</a></span></li><li><span><a href="#Available-Data-Views" data-toc-modified-id="Available-Data-Views-6.2">Available Data Views</a></span></li><li><span><a href="#Asset-Metadata" data-toc-modified-id="Asset-Metadata-6.3">Asset Metadata</a></span></li><li><span><a href="#Additional-Data-Sources" data-toc-modified-id="Additional-Data-Sources-6.4">Additional Data Sources</a></span></li></ul></li></ul></div>

# %% [markdown]
# # Overall Learning Objectives
#
# ## Introduction to the OSIsoft Academic Hub, Operational Data, and OSIsoft
#
# The OSIsoft Academic Hub is a cloud-based platform that enables experiential learning with industrial process datasets. Students use the Academic Hub to gain experience in solving real-world problems with real-world data. Students gain experience in several areas that help to prepare them for careers in today’s workplace:
#
# • Navigating broader, less defined problem statements
#
# • Evaluating multiple data sources and types to determine appropriateness for given context
#
# • Determining which data is extraneous, erroneous, or inaccurate
#
# • Integrating timeseries data with other types of data
#
# • Analyzing large datasets to improve business decisions
#
# • Working seamlessly in teams in person and remotely
#
# • Using industry current AI/ML platforms, visualization tools, and programming languages
#
# OSIsoft’s technology provides customers with the tools for real-time data management of their operational data. Operational data is data that reflects the physical state of an industrial asset (or “thing”). There are many sources and types of data in operations; real-time process control data, sensor and device data; machine-generated data, asset data, web data, weather data, heat map data, and many more. One of the unique types of operational data is time-series data, where time is the index. For over forty years OSIsoft has been at the forefront of time series data collection and aggregation, along with other types of operational data, allowing people to contextualize and federate large volumes of industrial, operational data. With 65% of industrial Fortune 500 customers using OSIsoft products to monitor over two billion data streams globally, it is likely engineers will work with an OSIsoft product during their career. Data analysis and specifically time series data analysis skills are quickly becoming a standard requirement for engineers and managers alike. OSIsoft data is ready to integrate into sophisticated visualization tools, industry applications and AI/ML platforms in use today globally.

# %% [markdown]
# ## Overview of the Campus Dataset Document
#
# __[Part 1](#section_1). Description of Campus Energy Dataset (UC Davis)__
#
# Describes the OSIsoft Academic Hub ([Part 1](#section_1)), the Campus Energy dataset, the time frame in which the dataset was compiled, data quality ([Part 1a](#section_1a)), and UC Davis Smart Campus goals. ([Part 1b](#section_1b)).
#
# __[Part 2](#section_2). The Smart Campus Challenges__
#
# Demonstrates real-time analytic and visualization capabilities to integrate, monitor, and diagnose central utilities and campus-wide facilities.
#
# __[Part 3](#section_3). Stream Data__
#
# Explains the main energy data streams collected on the campus.
#
# __[Part 4](#section_4). Data Quality__
#
# Faced with real-world data, students are expected to work with "dirty" data: data which contains errors and gaps. This section also describes various ways poor quality data arises.
#
# __[Part 5](#section_5). Assets, Data Views and Metadata__
#
# Hub Datasets are organized around a set of assets, each of the asset having at least a default data view. A data view is an OCS feature to extract interpolated data from multiple related streams, in a tabular form ready for data-driven applications or any data analysis tool. Specialized data views (subsets of the default data views) can also be defined, as is the case for this dataset.

# %% [markdown]
# # Part 1. Description of Campus Energy Dataset (UC Davis)
# ---
# <a id="section_1"></a>
#
#
# OSIsoft Academic Hub is a cloud-based platform that supports data analytics in the university curriculum by providing a data infrastructure to host, aggregate, and analyze data. Students are exposed to real-world industrial data which illustrates some of the same engineering concepts being taught in classrooms and labs. OSIsoft Academic Hub hosts the real-world dataset shared from a university customer, UC Davis. The dataset contains the sensor data and some calculations performed by UC Davis on-premises PI System. The entire dataset comes from 168 metered buildings during the timeframe of January 2017 to January 2020. All buildings have electricity data, and optionally chilled water and steam. The next sections list the buildings with indicators about the presence of electricity/chilled water/steam.

# %% [markdown]
# ### 1a. Presence of  electricity/chilled water/steam for each building
# <a id="section_1a"></a>
#
# As mentioned each building has at least electricity data (e.g. demand, usage). Data about chilled water and steam is also available for some buildings. The table below provides a summary per building about utility data.
#
# | # | Asset_Id (Building) | Electricity | Chilled Water | Steam
# |:--|:---------|:----:|:---:|:---:|
# | 1 | ARC Pavilion | &#9679; | &#9679; | &#9679; |
# | 2 | Academic Surge Building | &#9679; | &#9679; | &#9679; |
# | 3 | Activities and Recreation Center | &#9679; | &#9679; | &#9679; |
# | 4 | Advanced Materials Research Laboratory | &#9679; |  |  |
# | 5 | Advanced Transportation Infrastructure Research Center | &#9679; |  |  |
# | 6 | Agronomy Field Laboratory | &#9679; |  |  |
# | 7 | Animal Building | &#9679; |  |  |
# | 8 | Animal Resource Service J1 | &#9679; |  |  |
# | 156 | Vet Med Equine Athletic Performance Lab | &#9679; | &#9679; | &#9679; |
# | 157 | Vet Med Lab Animal A Beach Lab | &#9679; |  |  |
# | 158 | Vet Med Large Animal Facility | &#9679; |  |  |
# | 159 | Vet Med Student Services and Administration Center | &#9679; | &#9679; | &#9679; |
# | 160 | Veterinary Medicine 2 | &#9679; |  | &#9679; |
# | 161 | Voorhies Hall | &#9679; |  |  |
# | 162 | Walker Hall | &#9679; |  |  |
# | 163 | Water Science & Engineering Hydraulic L2 | &#9679; |  |  |
# | 164 | Watershed Science Facility | &#9679; | &#9679; | &#9679; |
# | 165 | Wellman Hall | &#9679; | &#9679; | &#9679; |
# | 166 | Western Human Nutrition Research Center (WHNRC) | &#9679; | &#9679; | &#9679; |
# | 167 | Wickson Hall | &#9679; | &#9679; | &#9679; |
# | 168 | Young Hall | &#9679; | &#9679; | &#9679; |

# %% [markdown]
# ### 1b. UC Davis Smart Campus
# <a id="section_1b"></a>
#
# OSIsoft Academic Hub contains real time data from many meters on the UC Davis campus that measure building electricity, heating (steam/condensate), cooling (chilled water), gas, and domestic water usage. The dataset also contains metadata on buildings (square footage, building type, construction date, etc.). This data set contains data for several years some meters at 10-second resolution.  The data is used for many student interactions; one example is seen here in the UC Davis Campus Energy Education Dashboard https://ceed.ucdavis.edu/.
#
# ![](https://academichub.blob.core.windows.net/images/ceed-ucdavis-landing-v2.png)
#
#
# Sustainability is very important to UC Davis as part of the larger University of California System, which has pledged to attain carbon neutrality by 2025. The Energy and Engineering department of Facilities Management stives to reduce the school's impact on the environment, while simultaneously reducing energy costs and educating students about energy usage and tradeoffs.
#
# * https://www.ucop.edu/carbon-neutrality-initiative/index.html
#
# * https://sustainability.ucdavis.edu/topics/buildings/index.html
#
# * https://facilities.ucdavis.edu/energy-engineering
#
# UC Davis has presented several times over the years at OSIsoft's PI World conference, telling their stories of getting started, campus wide energy management, student learning, and their journey towards carbon neutrality.
#
# * https://resources.osisoft.com/presentations/multidisciplinary-collaboration-for-student-education---uc-davis-pi-systems-for-learning-and-research/
#
# * https://resources.osisoft.com/presentations/uc-davis-path-to-carbon-neutrality-using-the-osisoft-pi-system/

# %% [markdown]
# # Part 2. Smart Campus Challenges and Goals
# ---
# <a id="section_2"></a>
#
# Some of the goals UC Davis wants to achieve include:
#
# * Monitor, diagnose and optimize on campus central utilities and campus-wide facilities including:
#     * Electricity, Water, Steam, Chilled Water, Purified Water
# * Allow campus operations to manage cross system demands and responses
# * Determine and predict building occupancy and related energy needs
# * Educate students about energy usage and impacts, to drive green behavior
#
# As a result of multiple initiatives, UC Davis is using less energy today than twenty years ago. This reduction occurred concurrent with a period of large campus growth (over 2.6M square feet of new building space and 6,300 additional students).
#
# * https://ceed.ucdavis.edu/energystory

# %% [markdown]
# # Part 3. Stream Data
# ---
# <a id="section_3"></a>
#
# The main stream of data for each of the three utilities, i.e. Electricity, Chilled Water and Steam is the one called 'Demand'. The respective units of measure are kW (kilo Watt), MTBU/h and lbs/h. To ease comparison and to calculate the total amount of energe consumed for a building, each of those stream have a companion stream called `Demand_kBtu` which is the respective `Demand` stream converted into kBtu unit.
#
# With the square footage per building provided by the metadata (see [Section 5, Metadata](#section_5_metadata)), it is possible to calculate the Energy Use Intensity defined as:
#
# $$ \tt{Energy\ Use\ Intensity} = \frac{\tt{Annual\ Energy\ Use\ (kBtu)}}{\tt{Building\ Square\ Footage\ (ft2)}} $$
#
# The EUI is computed for each utility and stored respectively in streams `Electricity_EUI`, `ChilledWater_EUI` and `Steam_EUI` respectively.
#
# The rest of the streams are a mix of Cumulative Use, Monthly and Annual Usage and different Rollover. Note that it's easy to recalculate those streams using the demand ones.

# %% [markdown]
# # Part 4. Data Quality
# ---
# <a id="section_4"></a>
#
# Dirty data is the result of numerous causes including: an error between the data source and the mechanism sending the data stream to the data store, propagation of poor quality data through its use in calculations, manual data being mis-keyed or mislabeled, and simply missing data. Another potential poor quality data can come from changes in equipment that are not accurately reflected in the instrumentation and control systems, such as a valve position that used to have digital states of ON/OFF being replaced with a valve with digital states of OFF/ON and no edits are made in the control system. Instrumentation errors can also contribute to dirty data, such as drift and simply being broken or in need of calibration.
#
# With the current version of Academic Hub Python library, data views will show all the dirty data value (except mislabeled ones) as missing data (empty string). Data cleansing must be performed before moving forward with data analysis. Data cleansing is the process of removing, editing, or adding incorrect or missing data from a raw data set. In the case of the fermenter data, the only type of data cleansing we need to perform is on missing data. Rows with missing data can be discarded from a Pandas dataframe by calling the `.dropna()` method. Some student exercises require this method for data preparation.

# %% [markdown]
# # Part 5. Assets, Dataviews and Metadata
# ---
# <a id="section_5"></a>

# %% [markdown]
# Academic Hub datasets are structured around assets. For the UC Davis Campus dataset, assets are buildings. Each asset has an Asset Identifier (Asset Id) and a description. This information is available through the Hub Python library (`ocs_academic_hub`) and is returned as a Pandas dataframe.
#
# Each asset is endowed with a default data view, i.e. a structure which maps all the data streams associated to the asset onto a column in a Pandas dataframe. Each data view has a Data view Id and exists within an OCS namespace, i.e. a named partition with its own Namespace ID. To request data for an asset, the following information should be provided:
#
# * Namespace Id
# * Data view Id
# * Start index (timestamp)
# * End index (timestamp).
# * Interpolation interval
#
# Reference for the start/end index and interpolation interval can be found at
# https://ocs-docs.osisoft.com/Content_Portal/Documentation/DataViews/GetDataViewData/Quick_Start_Get_Data_View_Data.html#index.
#
# For specific use-cases it is possible to define specialized dataviews having only a subset of the default dataview columns. Specialized dataviews avoid data over fetching and reduce the time to get results back especially with large tables with high number of rows. Most data views are for a single asset, but it's possible to define a data view spanning multiple assets. This avoid requesting multiple single-asset data views and stitching the result into a single Pandas dataframe for analysis.
#
# Asset metadata is static information about the asset, e.g. the year a building was built, square footage, and type of usage.

# %%
# -------------------------------
# Code preamble for next sections
# -------------------------------
from ocs_academic_hub.datahub import hub_login
from IPython.display import display, Markdown, HTML
import pandas as pd
dataset = "Campus_Energy"
widget, hub = hub_login()
display(widget)
hub.set_dataset(dataset)
namespace_id = hub.namespace_of(dataset)
def display_df(df):
    return display(df.style.hide_index())

# %% [markdown]
# ## Campus Assets: Buildings

# %%
display_df(hub.assets())
# Out:
# <style  type="text/css" >
# </style><table id="T_d3e74_" ><thead>    <tr>        <th class="col_heading level0 col0" >Asset_Id</th>        <th class="col_heading level0 col1" >Description</th>    </tr></thead><tbody>
#                 <tr>
#                                 <td id="T_d3e74_row0_col0" class="data row0 col0" >ARC Pavilion</td>
#                         <td id="T_d3e74_row0_col1" class="data row0 col1" >Building</td>
#             </tr>
#             <tr>
#                                 <td id="T_d3e74_row1_col0" class="data row1 col0" >Academic Surge Building</td>
#                         <td id="T_d3e74_row1_col1" class="data row1 col1" >Building</td>
#             </tr>
#             <tr>
#                                 <td id="T_d3e74_row2_col0" class="data row2 col0" >Activities and Recreation Center</td>
#                         <td id="T_d3e74_row2_col1" class="data row2 col1" >Building</td>
#             </tr>
#             <tr>
# ...

# %% [markdown]
# ## Available Data Views
#
# All assets have at least a default data view with ID of the following format: `campus.building-<asset_id>` where `<asset_id>` is the Asset Id as seen above but all lowercase and no space. Each default data view has an identical counterpart with Id `campus.building-<asset_id>-electricity`. The reason is that every building has electrical data, but chilled water and steam are optional. If chilled water and/or steam data are available for a building, their respective formats are `campus.building-<asset_id>-chilled_water` and `campus.building-<asset_id>-steam`.
#
# Using building with Asset_Id `ARC Pavilion` as a representative of such assets, the list all available single-asset data views can be obtained with:

# %%
dataview_ids = hub.asset_dataviews("ARC Pavilion")
dataview_ids
# Out:
# ['campus.building-arc_pavilion',
#  'campus.building-arc_pavilion-chilled_water',
#  'campus.building-arc_pavilion-electricity',
#  'campus.building-arc_pavilion-steam']

# %% [markdown]
# **Each data view has two versions: one for interpolated data and another for stored data. Check Quick Start notebook for usage examples.**
#
#
# The definition of each data view for building `ARC Pavilion` are given below (default and electricity have the same definitions):
#
# <div class="alert alert-block alert-warning">
# <b>NOTE: not all the buildings have all the streams shown below for a given data view, so please check that you have all the required columns for your analysis with your combined building and utility data selection.</b>
# </div>

# %%
for dv_id in dataview_ids:
    dv_df = hub.dataview_definition(namespace_id, dv_id)
    display(HTML("<hr></hr>"))
    display(
        Markdown(
            f'**Data view ID: <span style="color:blue">{dv_id}</span>** (# of streams: {len(dv_df.index)})'
        )
    )
    display_df(dv_df)
# Out:
# <hr></hr>
# **Data view ID: <span style="color:blue">campus.building-arc_pavilion</span>** (# of streams: 9)
# <style  type="text/css" >
# </style><table id="T_ae805_" ><thead>    <tr>        <th class="col_heading level0 col0" >Asset_Id</th>        <th class="col_heading level0 col1" >Column_Name</th>        <th class="col_heading level0 col2" >Stream_Type</th>        <th class="col_heading level0 col3" >Stream_UOM</th>        <th class="col_heading level0 col4" >Stream_Name</th>    </tr></thead><tbody>
#                 <tr>
#                                 <td id="T_ae805_row0_col0" class="data row0 col0" >ARC Pavilion</td>
#                         <td id="T_ae805_row0_col1" class="data row0 col1" >AnnualUsage</td>
#                         <td id="T_ae805_row0_col2" class="data row0 col2" >Float</td>
#                         <td id="T_ae805_row0_col3" class="data row0 col3" >kBtu</td>
# ...

# %% [markdown]
# ## Asset Metadata
#
# <a id="section_5_metadata"></a>
#
# Building metadata for `Campus_Energy` is a Python dictionary where key `CAAN` is a building code. The rest of the key are self-explanatory.

# %%
hub.asset_metadata("ARC Pavilion")
# Out:
# {'BuildingName': 'ARCPavilion',
#  'CAAN': 4444,
#  'Construction Date': 19770301,
#  'Display Name': 'ARC Pavilion',
#  'Latitude': 38.54181213318,
#  'Longitude': -121.75962444,
#  'Primary Usage (Type)': 'REC - Athletics & Recreation',
#  'Total Maintained Gross Sq. Ft.': 171940,
#  'chilledwater.Annual Cost': 557,
#  'chilledwater.tonh Rate': 0.1493,
#  'electricity.Annual Cost': 51155,
#  'electricity.kWh Rate': 0.0687,
#  'steam.Annual Cost': 1500,
#  'steam.klb Rate': 7.2552,
#  'Asset_Id': 'ARC Pavilion'}

# %% [markdown]
# ## Additional Data Sources
#
# Outside temperature at UC Davis campus has a course a big impact on the energy demand, either to heat or cool depending on the season. The data set has a data stream captured by a temperature sensor at the campus site in Farenheit. The code below shows how to access between the 2017-05 and 2018-05, every 15 minutes:

# %%
outside_temp_df = hub.stream_interpolated_pd(
    namespace_id, "PI_uni-pida-vm0_2603", "2017-05", "2018-05", "01:00:00"
)

outside_temp_df
# Out:
#                      Timestamp      Value
# 0    2017-05-01 00:00:00+00:00  85.750694
# 1    2017-05-01 01:00:00+00:00  85.156220
# 2    2017-05-01 02:00:00+00:00  82.239130
# 3    2017-05-01 03:00:00+00:00  77.571790
# 4    2017-05-01 04:00:00+00:00  74.654420
# ...                        ...        ...
# 8756 2018-04-30 20:00:00+00:00  68.063820
# 8757 2018-04-30 21:00:00+00:00  70.990555
# 8758 2018-04-30 22:00:00+00:00  73.905090
# 8759 2018-04-30 23:00:00+00:00  70.639250
# 8760 2018-05-01 00:00:00+00:00  72.736880
#
# [8761 rows x 2 columns]

# %%
import plotly.express as px
px.scatter(outside_temp_df, x="Timestamp", y="Value", title="Outside Temperature at UC Davis Campus Over Time", labels=dict(Timestamp= 'Time', Value='Temperature (F)'))
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# Also for your project, you may wish to combine the data from OSIsoft Cloud Services with data from other sources. For example, you may wish to consider the time-dependent cost of electricity. This dataset is available here (unit is $/MWh):
#
# * https://academichub.blob.core.windows.net/hub/campus_energy/RealTimeMarketRate.csv
#
# Also available is the building Wifi access for 2 years:
#
# * https://academichub.blob.core.windows.net/hub/campus_energy/ucdavis_wifi_data.csv
#
# To access the real time rate data as a Pandas dataframe you may use:

# %%
real_time_rate_df = pd.read_csv(
    "https://academichub.blob.core.windows.net/hub/campus_energy/RealTimeMarketRate.csv",
    names=["Timestamp", "Rate"],
    header=None,
)
real_time_rate_df
# Out:
#                  Timestamp         Rate
# 0       01-Nov-17 01:00:00   30.7713604
# 1       01-Nov-17 01:05:00  26.49471092
# 2       01-Nov-17 01:10:00  26.79637909
# 3       01-Nov-17 01:15:00  26.57773972
# 4       01-Nov-17 01:20:00   25.6127491
# ...                    ...          ...
# 235300  17-Jan-20 13:30:00  14.81171989
# 235301  17-Jan-20 13:35:00  17.24423027
# 235302  17-Jan-20 13:40:00  16.64229012
# 235303  17-Jan-20 13:45:00  15.86855984
# 235304  17-Jan-20 13:50:00   18.3388195
#
# [235305 rows x 2 columns]

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=f1a24daf-02e8-473d-ac7d-4f95d28af1b1' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
